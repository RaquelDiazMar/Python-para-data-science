# %%
import pandas as pd

# %%
df = pd.read_csv("C:/Users/34677/Documents/GitHub/Python para data science y big data esencial/base_datos_2008.csv", nrows=100000)
# el parámetro nrows limita el número de filas a leer del archivo

# %%
df.head()
# Out:
#    Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 0  2008      1           3          4   2003.0        1955   2211.0
# 1  2008      1           3          4    754.0         735   1002.0
# 2  2008      1           3          4    628.0         620    804.0
# 3  2008      1           3          4    926.0         930   1054.0
# 4  2008      1           3          4   1829.0        1755   1959.0
#
#    CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# 0        2225            WN        335  ...    4.0      8.0          0
# 1        1000            WN       3231  ...    5.0     10.0          0
# 2         750            WN        448  ...    3.0     17.0          0
# 3        1100            WN       1746  ...    3.0      7.0          0
# 4        1925            WN       3920  ...    3.0     10.0          0
#
#    CancellationCode  Diverted  CarrierDelay WeatherDelay NASDelay  \
# ...

# %%
df.head(10)
# Out:
#    Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 0  2008      1           3          4   2003.0        1955   2211.0
# 1  2008      1           3          4    754.0         735   1002.0
# 2  2008      1           3          4    628.0         620    804.0
# 3  2008      1           3          4    926.0         930   1054.0
# 4  2008      1           3          4   1829.0        1755   1959.0
# 5  2008      1           3          4   1940.0        1915   2121.0
# 6  2008      1           3          4   1937.0        1830   2037.0
# 7  2008      1           3          4   1039.0        1040   1132.0
# 8  2008      1           3          4    617.0         615    652.0
# 9  2008      1           3          4   1620.0        1620   1639.0
#
#    CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# 0        2225            WN        335  ...    4.0      8.0          0
# 1        1000            WN       3231  ...    5.0     10.0          0
# ...

# %%
df.tail()
# Out:
#        Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 99995  2008      1          25          5   2204.0        1935    106.0
# 99996  2008      1          26          6   1933.0        1935   2234.0
# 99997  2008      1          27          7   2047.0        1935   2400.0
# 99998  2008      1          28          1   1956.0        1935   2308.0
# 99999  2008      1          29          2   1938.0        1935   2308.0
#
#        CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# 99995        2257            XE       7676  ...    4.0     17.0          0
# 99996        2257            XE       7676  ...    4.0     16.0          0
# 99997        2257            XE       7676  ...    6.0     18.0          0
# 99998        2257            XE       7676  ...    5.0     25.0          0
# 99999        2257            XE       7676  ...    5.0     41.0          0
#
#        CancellationCode  Diverted  CarrierDelay WeatherDelay NASDelay  \
# ...

# %%
df.sample(frac=1)
# con frac=1 indicamos que queremos que mantenga el 100 % de las filas que tenemos.
# Out:
#        Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 57513  2008      1          20          7   1853.0        1845   2049.0
# 29567  2008      1          12          6    759.0         800    853.0
# 29793  2008      1          12          6   1458.0        1500   1551.0
# 19165  2008      1           9          3    643.0         645    836.0
# 15581  2008      1           8          2    954.0         950   1034.0
# ...     ...    ...         ...        ...      ...         ...      ...
# 32912  2008      1          13          7   1933.0        1930   2104.0
# 82177  2008      1          28          1    920.0         920   1215.0
# 80081  2008      1          27          7    712.0         710   1249.0
# 67512  2008      1          23          3    853.0         855   1041.0
# 52854  2008      1          19          6   1234.0        1225   1502.0
#
#        CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# ...

# %%
df=df.sample(frac=1)

# %%
df.columns
# no se utilizan paréntesis debido a que se refiere a un atributo del propio dataframe
# Out:
# Index(['Year', 'Month', 'DayofMonth', 'DayOfWeek', 'DepTime', 'CRSDepTime',
#        'ArrTime', 'CRSArrTime', 'UniqueCarrier', 'FlightNum', 'TailNum',
#        'ActualElapsedTime', 'CRSElapsedTime', 'AirTime', 'ArrDelay',
#        'DepDelay', 'Origin', 'Dest', 'Distance', 'TaxiIn', 'TaxiOut',
#        'Cancelled', 'CancellationCode', 'Diverted', 'CarrierDelay',
#        'WeatherDelay', 'NASDelay', 'SecurityDelay', 'LateAircraftDelay'],
#       dtype='object')

# %%
df.DepTime
# Out:
# 12847    2120.0
# 26423    1229.0
# 3231      600.0
# 22101    1024.0
# 9214     1129.0
#           ...
# 8279        NaN
# 86724    1523.0
# 59256    1339.0
# 27262    1136.0
# 38615    1355.0
# Name: DepTime, Length: 100000, dtype: float64

# %%
df.dtypes
# Out:
# Year                   int64
# Month                  int64
# DayofMonth             int64
# DayOfWeek              int64
# DepTime              float64
# CRSDepTime             int64
# ArrTime              float64
# CRSArrTime             int64
# UniqueCarrier         object
# FlightNum              int64
# TailNum               object
# ActualElapsedTime    float64
# CRSElapsedTime         int64
# AirTime              float64
# ArrDelay             float64
# DepDelay             float64
# Origin                object
# Dest                  object
# Distance               int64
# TaxiIn               float64
# TaxiOut              float64
# Cancelled              int64
# CancellationCode      object
# Diverted               int64
# CarrierDelay         float64
# WeatherDelay         float64
# NASDelay             float64
# SecurityDelay        float64
# LateAircraftDelay    float64
# dtype: object

# %%
df.values
# Out:
# array([[2008, 1, 7, ..., nan, nan, nan],
#        [2008, 1, 11, ..., nan, nan, nan],
#        [2008, 1, 4, ..., nan, nan, nan],
#        ...,
#        [2008, 1, 21, ..., nan, nan, nan],
#        [2008, 1, 11, ..., nan, nan, nan],
#        [2008, 1, 15, ..., nan, nan, nan]], dtype=object)

# %%
df2=df.head(10)

# %%
df2.head(20)
# Out:
#        Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 12847  2008      1           7          1   2120.0        2120   2211.0
# 26423  2008      1          11          5   1229.0        1230   1345.0
# 3231   2008      1           4          5    600.0         600    656.0
# 22101  2008      1           9          3   1024.0        1025   1300.0
# 9214   2008      1           6          7   1129.0        1130   1227.0
# 95377  2008      1          23          3   1505.0        1515   1644.0
# 48533  2008      1          17          4   2133.0        2110   2215.0
# 33835  2008      1          13          7   1658.0        1655   1757.0
# 2216   2008      1           3          4   1021.0        1025   1118.0
# 54732  2008      1          20          7   1714.0        1715   1916.0
#
#        CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# 12847        2215            WN         78  ...    3.0      7.0          0
# ...
